# %%
import pandas as pd

# %%
text = pd.read_csv('language_dataframe.csv')

# %%
text
# Out:
#     Unnamed: 0                       Authors  \
# 0            0                   Mark Hibben
# 1           13                 Michael Blair
# 2          282                      Alex Cho
# 3          288        The Structure Of Price
# 4          453                     Max Greve
# 5          458         Celeritas Investments
# 6          611                   Josh Arnold
# 7          655                    Labutes IR
# 8          729       Orange Peel Investments
# 9          731               Kayode Omotosho
# 10         804                  Daniel Jones
# 11         887                 Marten Ariens
# 12         890                   Taylor Dart
# 13         950               Activist Stocks
# 14         959                     Max Greve
# 15        1027                   Bill Maurer
# 16        1028                Quad 7 Capital
# 17        1119       Orange Peel Investments
# 18        1132                    Short Only
# 19        1198          Brian Gilmartin, CFA
# ...

# %%
text['Performance'].value_counts()
# Out:
# 0    33
# 1    23
# Name: Performance, dtype: int64

# %%
text['Perfor']

# %%
train = text[text['Date'] < '2017-10-01']
test = text[text['Date'] > '2017-10-01']

# %%
len(train)
# Out:
# 56

# %%
natural_language = pd.read_csv('Content.csv')
natural_language.head(1)
# Out:
#    Unnamed: 0                                                  0
# 0           0  Rethink Technology business briefs for July 21...

# %%
train_text = []
for row in range(0,len(X_train.index)):
    train_text.append(' '.join(str(x) for x in X_train))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
basicvectorizer = CountVectorizer()
basictrain = basicvectorizer.fit_transform(train_text)
print(basictrain.shape)
# Out:
# (2390, 59)

# %%
basicmodel = LogisticRegression()
basicmodel = basicmodel.fit(basictrain, train["Label"])
