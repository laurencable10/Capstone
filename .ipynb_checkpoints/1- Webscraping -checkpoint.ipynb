# %% [markdown]
# <img src="seekingalpha.png" style="float: left; margin: 20px; height: 55px">
#
# # Notebook 1- Webscraping
#
# #### _Webscraping Long and Short Ideas on Seeking Alpha_
#
# ---
# ### Notebook Summary
# - The method for acquiring data will be scraping the "Long Ideas" and "Short Ideas" threads as listed under Seeking Alpha's annalyses tab from 1/1/2017 through 1/31/2018
# - The Requests and Beautiful Soup libraries will be utilized to extract certain pieces of information about each article:
#      - The title of the article
#      - The author of the article
#      - The stock ticker that the article references
#      - The length of time the article has been up on Seeking Alpha
#      - The link of the article itself
# - The Pandas library and engineered functions will be leveraged to transform the webscrape results into DataFrames
# - The DataFrames will be saved and exported as csv files for accessibility throughout the remainder of the notebooks, most specifically in order to clean (Notebook 2) and perform Exploratory Data Analysis (Notebook 3)
# ---

# %%
# Importing necessary libraries 
import pandas as pd
import requests
import time
from bs4 import BeautifulSoup

# %% [markdown]
# ---
# ## Webscraping
# ---
# ### _Long Ideas_

# %%
long_request_list = []  # Creating empty list to append results to 

for i in range(48,235):  
    # Range (x,x) indicates pages being scraped
    # Pages selected to scrape selected dates 
    response = requests.get("https://seekingalpha.com/stock-ideas/long-ideas?page="+str(i), 
    headers = {'User-agent': '-----lauren'}) 
        # 'str(i)' indicates page number being scraped  
        #  Introducing header and delay between each request- polite web scraping practices 
    time.sleep(30)  
    print(response.status_code) 
    if response.status_code == 200: # Scraping/parsing HTML only if proper connection made 
        html = response.text    
        soup = BeautifulSoup(html,'lxml') 
        long_request_list.append(soup)   # Appending results to empty list
    print(f'(https://seekingalpha.com/stock-ideas/long-ideas?page={str(i)})')
    print(i)
# Out:
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=48)
# 48
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=49)
# 49
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=50)
# 50
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=51)
# 51
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=52)
# 52
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=53)
# 53
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=54)
# 54
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=55)
# 55
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=56)
# 56
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=57)
# 57
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=58)
# 58
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=59)
# 59
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=60)
# 60
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=61)
# 61
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=62)
# 62
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=63)
# 63
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=64)
# 64
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=65)
# 65
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=66)
# 66
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=67)
# 67
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=68)
# 68
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=69)
# 69
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=70)
# 70
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=71)
# 71
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=72)
# 72
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=73)
# 73
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=74)
# 74
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=75)
# 75
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=76)
# 76
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=77)
# 77
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=78)
# 78
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=79)
# 79
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=80)
# 80
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=81)
# 81
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=82)
# 82
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=83)
# 83
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=84)
# 84
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=85)
# 85
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=86)
# 86
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=87)
# 87
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=88)
# 88
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=89)
# 89
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=90)
# 90
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=91)
# 91
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=92)
# 92
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=93)
# 93
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=94)
# 94
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=95)
# 95
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=96)
# 96
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=97)
# 97
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=98)
# 98
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=99)
# 99
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=100)
# 100
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=101)
# 101
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=102)
# 102
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=103)
# 103
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=104)
# 104
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=105)
# 105
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=106)
# 106
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=107)
# 107
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=108)
# 108
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=109)
# 109
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=110)
# 110
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=111)
# 111
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=112)
# 112
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=113)
# 113
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=114)
# 114
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=115)
# 115
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=116)
# 116
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=117)
# 117
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=118)
# 118
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=119)
# 119
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=120)
# 120
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=121)
# 121
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=122)
# 122
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=123)
# 123
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=124)
# 124
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=125)
# 125
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=126)
# 126
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=127)
# 127
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=128)
# 128
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=129)
# 129
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=130)
# 130
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=131)
# 131
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=132)
# 132
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=133)
# 133
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=134)
# 134
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=135)
# 135
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=136)
# 136
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=137)
# 137
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=138)
# 138
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=139)
# 139
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=140)
# 140
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=141)
# 141
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=142)
# 142
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=143)
# 143
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=144)
# 144
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=145)
# 145
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=146)
# 146
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=147)
# 147
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=148)
# 148
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=149)
# 149
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=150)
# 150
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=151)
# 151
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=152)
# 152
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=153)
# 153
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=154)
# 154
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=155)
# 155
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=156)
# 156
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=157)
# 157
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=158)
# 158
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=159)
# 159
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=160)
# 160
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=161)
# 161
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=162)
# 162
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=163)
# 163
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=164)
# 164
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=165)
# 165
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=166)
# 166
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=167)
# 167
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=168)
# 168
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=169)
# 169
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=170)
# 170
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=171)
# 171
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=172)
# 172
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=173)
# 173
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=174)
# 174
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=175)
# 175
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=176)
# 176
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=177)
# 177
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=178)
# 178
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=179)
# 179
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=180)
# 180
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=181)
# 181
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=182)
# 182
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=183)
# 183
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=184)
# 184
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=185)
# 185
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=186)
# 186
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=187)
# 187
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=188)
# 188
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=189)
# 189
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=190)
# 190
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=191)
# 191
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=192)
# 192
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=193)
# 193
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=194)
# 194
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=195)
# 195
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=196)
# 196
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=197)
# 197
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=198)
# 198
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=199)
# 199
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=200)
# 200
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=201)
# 201
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=202)
# 202
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=203)
# 203
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=204)
# 204
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=205)
# 205
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=206)
# 206
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=207)
# 207
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=208)
# 208
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=209)
# 209
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=210)
# 210
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=211)
# 211
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=212)
# 212
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=213)
# 213
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=214)
# 214
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=215)
# 215
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=216)
# 216
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=217)
# 217
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=218)
# 218
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=219)
# 219
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=220)
# 220
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=221)
# 221
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=222)
# 222
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=223)
# 223
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=224)
# 224
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=225)
# 225
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=226)
# 226
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=227)
# 227
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=228)
# 228
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=229)
# 229
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=230)
# 230
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=231)
# 231
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=232)
# 232
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=233)
# 233
# 200
# (https://seekingalpha.com/stock-ideas/long-ideas?page=234)
# 234

# %% [markdown]
# ### _Short Ideas_

# %%
short_request_list = []  # Creating empty list to append soup results to 

for i in range(5,28):  
    # Range (x,x) indicates pages being scraped
    # Pages selected to scrape selected dates 
    response = requests.get("https://seekingalpha.com/stock-ideas/short-ideas?page="+str(i),
    headers = {'User-agent': 'LaurenCable-GeneralAssemblyCapstone-6787994961-laurencable10@gmail.com'})
        # 'str(i)' indicates page number being scraped  
        #  Introducing header and delay between each request- polite web scraping practices 
    time.sleep(30)     
    print(response.status_code)  
    if response.status_code == 200: # Scraping/parsing HTML only if proper connection made 
        html = response.text         
        soup = BeautifulSoup(html,'lxml')  
        short_request_list.append(soup)   # Appending results to empty list
    print(f'(https://seekingalpha.com/stock-ideas/short-ideas?page={str(i)})')
    print(i)
# Out:
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=5)
# 5
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=6)
# 6
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=7)
# 7
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=8)
# 8
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=9)
# 9
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=10)
# 10
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=11)
# 11
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=12)
# 12
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=13)
# 13
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=14)
# 14
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=15)
# 15
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=16)
# 16
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=17)
# 17
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=18)
# 18
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=19)
# 19
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=20)
# 20
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=21)
# 21
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=22)
# 22
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=23)
# 23
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=24)
# 24
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=25)
# 25
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=26)
# 26
# 200
# (https://seekingalpha.com/stock-ideas/short-ideas?page=27)
# 27

# %% [markdown]
# ---
# ## Extracting Desired Data
# ---
# ### _Long Ideas_

# %%
# Function to extract titles

def extract_longideas_titles(long_request_list):
    longideas_titles = []   # Creating empty list to append article titles to 
    for i in long_request_list:  # Iterating through scraped results 
        for each in i.find_all('a',{'class':'a-title'}): # Calling proper HTML tags/classes 
            longideas_titles.append(each.text)  # Appending text data to empty list
    return(longideas_titles)

# Setting function as variable
fetch_longideas_titles = extract_longideas_titles(long_request_list)

# %%
# Function to extract links

def extract_longideas_links(long_request_list):
    longideas_links = []    # Creating empty list to append article links to 
    for i in long_request_list:  # Iterating through scraped results 
        for each in i.find_all('div',{'class':'media-body'}): # Calling proper HTML tags/classes
            result = each.find('a')
            if result:
                link = result['href']
                longideas_links.append(link) # Appending data to empty list
    return(longideas_links)

# Setting function as variable
fetch_longideas_links = extract_longideas_links(long_request_list)

# %%
# Function to extract author, ticker, and time posted 

def extract_longideas_multi(long_request_list):
    longideas_multi = [] # Creating empty list to append requests to
    for i in long_request_list: # Iterating through requests
        for each in i.find_all('div',{'class':'a-info'}): # Calling proper HTML tags/classes
            results = each.find_all('span')
            longideas_multi.append(each.text) # Appending text data to empty list
    return(longideas_multi)

# Setting function as variable 
fetch_longideas_multi = extract_longideas_multi(long_request_list)

# Text for all 3 features in 1 string, separated by bullets
fetch_longideas_multi[:3]
# Out:
# ['WFC• Mon, Jan. 15, 8:57 AM • FIG Ideas•7\xa0Comments',
#  'TSLA• Mon, Jan. 15, 8:21 AM • Nick Cox•466\xa0Comments',
#  'BTE• Mon, Jan. 15, 8:19 AM • Long Player•93\xa0Comments']

# %%
# In order to separate attribute in the string above
#
# Transforming results into DataFrame 

longideas_df = pd.DataFrame({'Multi':fetch_longideas_multi})
longideas_df.head(3)

# Utilizing bullet as delimiter
#
# str-split and extract each attribute via indexing position
longideas_tickers = longideas_df['Multi'].str.split('•').str.get(0)
longideas_times = longideas_df['Multi'].str.split('•').str.get(1)
longideas_authors = longideas_df['Multi'].str.split('•').str.get(2)

# %% [markdown]
# ### _Short Ideas_

# %%
# Function to extract titles

def extract_shortideas_titles(short_request_list):  
    shortideas_titles = []  # Creating empty list to append article titles to
    for i in short_request_list:  # Iterating through scraped results 
        for each in i.find_all('a',{'class':'a-title'}): # Calling proper HTML tags/classes   
                shortideas_titles.append(each.text) # Appending text data to empty list 
    return(shortideas_titles)

# Setting function as variable
fetch_shortideas_titles = extract_shortideas_titles(short_request_list)

# %%
# Function to extract links

def extract_shortideas_links(short_request_list):
    shortideas_links = []   # Creating empty list to append article links to
    for i in short_request_list:  # Iterating through scraped results
        for each in i.find_all('div',{'class':'media-body'}): # Calling proper HTML tags/classes 
            result = each.find('a')
            if result:
                link = result['href']
                shortideas_links.append(link) # Appending data to empty list 
    return(shortideas_links)

# Setting function as variable
fetch_shortideas_links = extract_shortideas_links(short_request_list)

# %%
# Function to extract author, ticker, and time posted 

def extract_shortideas_multi(short_request_list):
    shortideas_multi = [] # Creating empty list to append requests to
    for i in short_request_list: # Iterating through requests
        for each in i.find_all('div',{'class':'a-info'}): # Calling proper HTML tags/classes
            results = each.find_all('span')
            shortideas_multi.append(each.text) # Appending text data to empty list
    return(shortideas_multi)

# Set function as variable 
fetch_shortideas_multi = extract_shortideas_multi(short_request_list)

# Text for all 3 features in 1 string, separated by bullets
fetch_shortideas_multi[:3]
# Out:
# ['CROX• Thu, Jan. 18, 7:30 AM • ALT Perspective',
#  'TSLA• Wed, Jan. 17, 5:09 PM • Bill Maurer•410\xa0Comments',
#  'HAWK• Wed, Jan. 17, 4:58 PM • Friedrich Chen•6\xa0Comments']

# %%
# In order to separate attribute in the string above
#
# Transforming results into DataFrame 

shortideas_df = pd.DataFrame({'Multi':fetch_shortideas_multi})
shortideas_df.head(3)

# Utilizing bullet as delimiter
#
# str-split and extract each attribute via indexing position

shortideas_tickers = shortideas_df['Multi'].str.split('•').str.get(0)
shortideas_times = shortideas_df['Multi'].str.split('•').str.get(1)
shortideas_authors = shortideas_df['Multi'].str.split('•').str.get(2)

# %% [markdown]
# ---
# ## Transforming Results into "Ideas " DataFrames
# ---
# ### _Long Ideas_

# %%
# Appending results to dataframes

longideas = pd.DataFrame({'Time': longideas_times,'Link': fetch_longideas_links,
                          'Title':fetch_longideas_titles,'Authors': longideas_authors,
                          'Tickers': longideas_tickers})

# %%
longideas['Strategy'] = 'Long' # Adding column for strategy type

# %% [markdown]
# ### _Short Ideas_

# %%
# Appending results to dataframe

shortideas = pd.DataFrame({'Time': shortideas_times,'Link': fetch_shortideas_links,
                          'Title': fetch_shortideas_titles,'Authors': shortideas_authors,
                           'Tickers': shortideas_tickers})

# %%
shortideas['Strategy'] = 'Short' # Adding column for strategy type

# %% [markdown]
# ### _ Ideas DataFrame_

# %%
ideas = pd.concat([longideas,shortideas])  # Merging long and short ideas

# %% [markdown]
# ---
# ## Saving Results
# ---

# %%
# Exporting Ideas dataframe as csv
ideas.to_csv('ideas_df.csv',index=False)

# %% [markdown]
# ## Onwards!
#
# ---
#
# ## Please proceed to Notebook 2 :)
